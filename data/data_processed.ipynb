# %%
import pickle

data_path = "/home/zxd/zxd/Huawei/lora-diffusion/data/temp_split/train_data.pkl"
with open(data_path, 'rb') as f:
    data = pickle.load(f)

print(type(data))
for item in data:
    print(item.shape)
# Out:
# <class 'list'>
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# (2048, 16)
# (16, 2048)
# (64, 16)
# (16, 64)
# ...
